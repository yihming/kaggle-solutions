# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LinearRegression 
from train import load_data

# %%
market, news = load_data()
market.describe()
market.plot(kind = 'line')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-1df384b00e4c> in <module>()
#       1 market, news = load_data()
#       2 market.describe()
# ----> 3 market.plot(kind = 'line')
#
# /home/yihming/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
news.describe()
# Out:
#        urgency  takeSequence     bodySize  companyCount  sentenceCount  \
# count   100.00    100.000000   100.000000     100.00000     100.000000
# mean      2.98      1.190000  3082.640000       3.53000      30.840000
# std       0.20      0.394277  2227.558475       2.13889      28.340185
# min       1.00      1.000000     0.000000       1.00000       1.000000
# 25%       3.00      1.000000  1404.250000       1.00000      11.000000
# 50%       3.00      1.000000  2409.500000       3.50000      22.500000
# 75%       3.00      1.000000  4638.000000       5.00000      47.000000
# max       3.00      2.000000  9674.000000       9.00000      96.000000
#
#          wordCount  firstMentionSentence   relevance  sentimentClass  \
# count   100.000000            100.000000  100.000000      100.000000
# mean    572.580000              7.750000    0.496374        0.060000
# std     423.258289             10.526902    0.360919        0.826579
# ...
